# %% [markdown]
# #🏠 Rental Apartment on Den Haag 📈💰

# %%
#install library deep translator
# !pip3 install deep-translator
# Out:
# Requirement already satisfied: deep-translator in /usr/local/lib/python3.7/dist-packages (1.5.5)
# Requirement already satisfied: click<9.0.0,>=8.0.1 in /usr/local/lib/python3.7/dist-packages (from deep-translator) (8.0.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.7/dist-packages (from deep-translator) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from deep-translator) (2.23.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.3.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click<9.0.0,>=8.0.1->deep-translator) (4.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click<9.0.0,>=8.0.1->deep-translator) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click<9.0.0,>=8.0.1->deep-translator) (3.6.0)

# %%
#import library
import tweepy
import numpy as np
import pandas as pd
import seaborn as sns
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from textblob import TextBlob
from wordcloud import WordCloud
from deep_translator import GoogleTranslator
import re
import string
string.punctuation
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.ensemble import RandomForestClassifier
import math
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from bs4 import BeautifulSoup
import requests
from csv import writer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #✅ Data Scraping

# %%
#generate url apartment
url = 'https://www.pararius.com/apartments/den-haag?ac=1'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'lxml')

# %%
#find dataset apartment
lists = soup.find_all('section', class_ = 'listing-search-item')

# %%
#export apartment dataset to csv file
with open('rental_apartment.csv', 'w', encoding = 'utf8', newline = '') as f:
    thewriter = writer(f)
    header = ['Name', 'Location', 'Area', 'Price']
    thewriter.writerow(header)
    
    for list in lists:
        name = list.find('a', class_ = 'listing-search-item__link--title').get_text().replace('\n', '')
        location = list.find('div', class_ = 'listing-search-item__location').get_text().replace('\n', '')
        area = list.find('li', class_ = 'illustrated-features__item illustrated-features__item--surface-area').get_text().replace('\n', '')
        price = list.find('div', class_ = 'listing-search-item__price').get_text().replace('\n', '')
        
        table = [name, location, area, price]
        thewriter.writerow(table)

# %%
#generate API twitter
api_key = "m0yhpABTodHrfgeS7fqFbs5MJ"
api_secret_key = "L0ehY3VnoTGkc4LU5RiYyGXLRPIs3Hzza7fWs0eCKrzGxEt5qX"
access_token = "1438478123880779777-4JuqCNOauTIJ7df2aZvx98axUNWNtI"
access_token_secret = "Q8umqtGUH7AtajlO5QaN7UPxn1gF4MKNQCeJ3Vi1p3tL9"

# %%
#authentication API twitter
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#find dataset tweet apartment
username = 'Pararius'
count = 30

#define function to create dataframe
try:     
     tweets = tweepy.Cursor(api.user_timeline, id = username).items(count)
     tweets_list = [[tweet.id, tweet.created_at, tweet.text] for tweet in tweets]
     tweets_df = pd.DataFrame(tweets_list)
        
except BaseException as e:
     print('failed on_status,', str(e))

#export to csv file
tweets_df.to_csv('tweet_apartment.csv')

# %% [markdown]
# #✅ Data Extraction

# %%
price = pd.read_csv('rental_apartment.csv')
tweet = pd.read_csv('tweet_apartment.csv')

# %%
price.head()
# Out:
#                         Name  ...                                         Price
# 0  Apartment Melis Stokelaan  ...                    €505 per month
# 1   Apartment Loosduinsekade  ...                  €1,395 per month
# 2        Apartment Maystraat  ...                  €1,495 per month
# 3     Apartment Altingstraat  ...                  €1,175 per month
# 4     Apartment Stevinstraat  ...                  €1,350 per month
#
# [5 rows x 4 columns]

# %%
price.shape
# Out:
# (30, 4)

# %%
tweet.head()
# Out:
#    Unnamed: 0  ...                                                  2
# 0           0  ...  “8 op de 10 starters ervaren de huidige ##woni...
# 1           1  ...  🏠 Vrije sector huurprijzen weer in de lift! ⬆️...
# 2           2  ...  Starters opgelet! 🏠 Help jij ons met het in ka...
# 3           3  ...  De gemiddelde m2 prijs van #huurwoningen in de...
# 4           4  ...  Deze maand in @Vastgoedactueel: waarom het van...
#
# [5 rows x 4 columns]

# %%
tweet.shape
# Out:
# (30, 4)

# %% [markdown]
# #✅ Data Preprocessing

# %%
#drop attribute Unnamed: 0
tweet = tweet.drop('Unnamed: 0', 1)
tweet.head()
# Out:
#                      0  ...                                                  2
# 0  1455814114111016962  ...  “8 op de 10 starters ervaren de huidige ##woni...
# 1  1448564109549649920  ...  🏠 Vrije sector huurprijzen weer in de lift! ⬆️...
# 2  1420647251282649088  ...  Starters opgelet! 🏠 Help jij ons met het in ka...
# 3  1415224609914462208  ...  De gemiddelde m2 prijs van #huurwoningen in de...
# 4  1395383581254488068  ...  Deze maand in @Vastgoedactueel: waarom het van...
#
# [5 rows x 3 columns]

# %%
#rename attribute
tweet = tweet.rename(columns = {'0' : 'ID', '1' : 'Datetime', '2' : 'Tweet'})
tweet.head()
# Out:
#                     ID  ...                                              Tweet
# 0  1455814114111016962  ...  “8 op de 10 starters ervaren de huidige ##woni...
# 1  1448564109549649920  ...  🏠 Vrije sector huurprijzen weer in de lift! ⬆️...
# 2  1420647251282649088  ...  Starters opgelet! 🏠 Help jij ons met het in ka...
# 3  1415224609914462208  ...  De gemiddelde m2 prijs van #huurwoningen in de...
# 4  1395383581254488068  ...  Deze maand in @Vastgoedactueel: waarom het van...
#
# [5 rows x 3 columns]

# %%
#join data from each table
join = (price, tweet['Tweet'])
df = pd.concat(join, axis = True)
df.head()
# Out:
#                         Name  ...                                              Tweet
# 0  Apartment Melis Stokelaan  ...  “8 op de 10 starters ervaren de huidige ##woni...
# 1   Apartment Loosduinsekade  ...  🏠 Vrije sector huurprijzen weer in de lift! ⬆️...
# 2        Apartment Maystraat  ...  Starters opgelet! 🏠 Help jij ons met het in ka...
# 3     Apartment Altingstraat  ...  De gemiddelde m2 prijs van #huurwoningen in de...
# 4     Apartment Stevinstraat  ...  Deze maand in @Vastgoedactueel: waarom het van...
#
# [5 rows x 5 columns]

# %%
#tidy up of structure table
df = df[['Name', 'Location', 'Tweet', 'Area', 'Price']]
df.head()
# Out:
#                         Name  ...                                         Price
# 0  Apartment Melis Stokelaan  ...                    €505 per month
# 1   Apartment Loosduinsekade  ...                  €1,395 per month
# 2        Apartment Maystraat  ...                  €1,495 per month
# 3     Apartment Altingstraat  ...                  €1,175 per month
# 4     Apartment Stevinstraat  ...                  €1,350 per month
#
# [5 rows x 5 columns]

# %%
#translate tweet from netherland to english language
translator = GoogleTranslator(source = 'NL', target = 'en') 
df['Tweet_Translated'] = df['Tweet'].apply(lambda x: translator.translate(x))

#drop description
df = df.drop('Tweet', 1)

#tidy up the table field
df = df[['Name', 'Location', 'Tweet_Translated', 'Area', 'Price']]

#rename attribute
df = df.rename(columns = {'Tweet_Translated' : 'Tweet'})
df.head()
# Out:
#                         Name  ...                                         Price
# 0  Apartment Melis Stokelaan  ...                    €505 per month
# 1   Apartment Loosduinsekade  ...                  €1,395 per month
# 2        Apartment Maystraat  ...                  €1,495 per month
# 3     Apartment Altingstraat  ...                  €1,175 per month
# 4     Apartment Stevinstraat  ...                  €1,350 per month
#
# [5 rows x 5 columns]

# %%
#re-format area column
df['Area'].dtype
area = []

for item in df['Area']:
    area.append(int(item.replace('m²','')))
    
df['Area'] = area
df.head()
# Out:
#                         Name  ...                                         Price
# 0  Apartment Melis Stokelaan  ...                    €505 per month
# 1   Apartment Loosduinsekade  ...                  €1,395 per month
# 2        Apartment Maystraat  ...                  €1,495 per month
# 3     Apartment Altingstraat  ...                  €1,175 per month
# 4     Apartment Stevinstraat  ...                  €1,350 per month
#
# [5 rows x 5 columns]

# %%
#re-format price column
df['Price'].dtype
price = []

for item in df['Price']:
    price.append(int(item.replace('€','').replace(',', '').replace('per month', '')))
    
df['Price'] = price
df.head()
# Out:
#                         Name  ... Price
# 0  Apartment Melis Stokelaan  ...   505
# 1   Apartment Loosduinsekade  ...  1395
# 2        Apartment Maystraat  ...  1495
# 3     Apartment Altingstraat  ...  1175
# 4     Apartment Stevinstraat  ...  1350
#
# [5 rows x 5 columns]

# %%
df.describe()
# Out:
#              Area        Price
# count   30.000000    30.000000
# mean    64.300000  1224.666667
# std     30.601048   353.426414
# min     20.000000   505.000000
# 25%     33.500000  1057.500000
# 50%     65.500000  1210.000000
# 75%     79.750000  1471.250000
# max    142.000000  2000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      30 non-null     object
#  1   Location  30 non-null     object
#  2   Tweet     30 non-null     object
#  3   Area      30 non-null     int64
#  4   Price     30 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.3+ KB

# %%
#heatmap correlation
plt.figure(figsize = (8,6))
sns.heatmap(df.corr(), annot = True, square = True)
plt.title("Pearson Correlation")
plt.show()

# %% [markdown]
# #✅ Text Processing (Natural Language Processing)

# %%
#selection data
text = df[['Tweet']]
text.head()
# Out:
#                                                Tweet
# 0  “8 out of 10 starters experience the current #...
# 1  🏠 Free sector rental prices on the rise again!...
# 2  Attention starters! 🏠 Will you help us map the...
# 3  The average m2 price of #rental homes in the #...
# 4  This month in @Vastgoedactueel: why it is impo...

# %% [markdown]
# ##🆎 Removal Punctuation

# %%
#defining to remove punctuation
def remove_punctuation(text):
    punctuationfree = "".join([i for i in text if i not in string.punctuation])
    return punctuationfree

text['Tweet_Punctuation'] = text['Tweet'].apply(lambda text: remove_punctuation(text))
text.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                Tweet                                  Tweet_Punctuation
# 0  “8 out of 10 starters experience the current #...  “8 out of 10 starters experience the current h...
# 1  🏠 Free sector rental prices on the rise again!...  🏠 Free sector rental prices on the rise again ...
# 2  Attention starters! 🏠 Will you help us map the...  Attention starters 🏠 Will you help us map the ...
# 3  The average m2 price of #rental homes in the #...  The average m2 price of rental homes in the fr...
# 4  This month in @Vastgoedactueel: why it is impo...  This month in Vastgoedactueel why it is import...

# %% [markdown]
# ##🆎 Removal Emoji

# %%
#defining the function to remove emoji
def remove_emoji(string):
    emoji_pattern = re.compile("["u"\U0001F600-\U0001F64F" u"\U0001F300-\U0001F5FF" u"\U0001F680-\U0001F6FF" u"\U0001F1E0-\U0001F1FF" u"\U00002702-\U000027B0" u"\U000024C2-\U0001F251""]+", flags = re.UNICODE)
    return emoji_pattern.sub(r'', string)

#applying the function
text['No_Emoji'] = text['Tweet_Punctuation'].apply(lambda x: remove_emoji(x))
text.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                                Tweet  ...                                           No_Emoji
# 0  “8 out of 10 starters experience the current #...  ...  “8 out of 10 starters experience the current h...
# 1  🏠 Free sector rental prices on the rise again!...  ...   Free sector rental prices on the rise again  ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  Attention starters  Will you help us map the p...
# 3  The average m2 price of #rental homes in the #...  ...  The average m2 price of rental homes in the fr...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  This month in Vastgoedactueel why it is import...
#
# [5 rows x 3 columns]

# %% [markdown]
# ##🆎 Removal HTML Attribute

# %%
#defining the function to remove html attribute
def remove_html(text):
    html_pattern = re.compile(r'https?://\S+|www\.\S+')
    return html_pattern.sub(r'', text)

#applying function to the column
text['Tweet_Clean'] = text['No_Emoji'].apply(lambda x: remove_html(x))
text.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                                Tweet  ...                                        Tweet_Clean
# 0  “8 out of 10 starters experience the current #...  ...  “8 out of 10 starters experience the current h...
# 1  🏠 Free sector rental prices on the rise again!...  ...   Free sector rental prices on the rise again  ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  Attention starters  Will you help us map the p...
# 3  The average m2 price of #rental homes in the #...  ...  The average m2 price of rental homes in the fr...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  This month in Vastgoedactueel why it is import...
#
# [5 rows x 4 columns]

# %% [markdown]
# ##🆎 Lower Casing

# %%
#setting lower case
text['Tweet_Lower'] = text['Tweet_Clean'].str.lower()
text.head()
# Out:
#                                                Tweet  ...                                        Tweet_Lower
# 0  “8 out of 10 starters experience the current #...  ...  “8 out of 10 starters experience the current h...
# 1  🏠 Free sector rental prices on the rise again!...  ...   free sector rental prices on the rise again  ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  attention starters  will you help us map the p...
# 3  The average m2 price of #rental homes in the #...  ...  the average m2 price of rental homes in the fr...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  this month in vastgoedactueel why it is import...
#
# [5 rows x 5 columns]

# %% [markdown]
# ##🆎 Tokenization

# %%
#defining function for tokenization
def tokenization(text):
    tokens = re.split('W+', text)
    return tokens

#applying function to the column
text['Tweet_Tokenied'] = text['Tweet_Lower'].apply(lambda x: tokenization(x))
text.head()
# Out:
#                                                Tweet  ...                                     Tweet_Tokenied
# 0  “8 out of 10 starters experience the current #...  ...  [“8 out of 10 starters experience the current ...
# 1  🏠 Free sector rental prices on the rise again!...  ...  [ free sector rental prices on the rise again ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  [attention starters  will you help us map the ...
# 3  The average m2 price of #rental homes in the #...  ...  [the average m2 price of rental homes in the f...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  [this month in vastgoedactueel why it is impor...
#
# [5 rows x 6 columns]

# %% [markdown]
# ##🆎 Removal Stopwords

# %%
#stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')

#defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

#applying the function
text['No_Stopwords'] = text['Tweet_Tokenied'].apply(lambda x:remove_stopwords(x))
text.head()
# Out:
#                                                Tweet  ...                                       No_Stopwords
# 0  “8 out of 10 starters experience the current #...  ...  [“8 out of 10 starters experience the current ...
# 1  🏠 Free sector rental prices on the rise again!...  ...  [ free sector rental prices on the rise again ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  [attention starters  will you help us map the ...
# 3  The average m2 price of #rental homes in the #...  ...  [the average m2 price of rental homes in the f...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  [this month in vastgoedactueel why it is impor...
#
# [5 rows x 7 columns]

# %% [markdown]
# ##🆎 Stemming

# %%
#defining the object for stemming
porter_stemmer = PorterStemmer()

#defining a function for stemming
def stemming(text):
    stem_text = [porter_stemmer.stem(word) for word in text]
    return stem_text

#applying the function
text['Tweet_Stemmed'] = text['No_Stopwords'].apply(lambda x: stemming(x))
text.head()
# Out:
#                                                Tweet  ...                                      Tweet_Stemmed
# 0  “8 out of 10 starters experience the current #...  ...  [“8 out of 10 starters experience the current ...
# 1  🏠 Free sector rental prices on the rise again!...  ...  [ free sector rental prices on the rise again ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  [attention starters  will you help us map the ...
# 3  The average m2 price of #rental homes in the #...  ...  [the average m2 price of rental homes in the f...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  [this month in vastgoedactueel why it is impor...
#
# [5 rows x 8 columns]

# %% [markdown]
# ##🆎 Lemmatization

# %%
#defining the object for lemmatizing
lemmatizer = WordNetLemmatizer()

#defining a function for lemmatizing
def lemmatize_words(text):
    lemma_text = [lemmatizer.lemmatize(word) for word in text]
    return lemma_text
                
#applying the function
text['Tweet_lemmatized'] = text['Tweet_Stemmed'].apply(lambda text: lemmatize_words(text))
text.head()
# Out:
#                                                Tweet  ...                                   Tweet_lemmatized
# 0  “8 out of 10 starters experience the current #...  ...  [“8 out of 10 starters experience the current ...
# 1  🏠 Free sector rental prices on the rise again!...  ...  [ free sector rental prices on the rise again ...
# 2  Attention starters! 🏠 Will you help us map the...  ...  [attention starters  will you help us map the ...
# 3  The average m2 price of #rental homes in the #...  ...  [the average m2 price of rental homes in the f...
# 4  This month in @Vastgoedactueel: why it is impo...  ...  [this month in vastgoedactueel why it is impor...
#
# [5 rows x 9 columns]

# %% [markdown]
# #✅ Sentiment Analysis

# %%
#selection data
df_new = text[['Tweet_Clean']]
df_new.head()
# Out:
#                                          Tweet_Clean
# 0  “8 out of 10 starters experience the current h...
# 1   Free sector rental prices on the rise again  ...
# 2  Attention starters  Will you help us map the p...
# 3  The average m2 price of rental homes in the fr...
# 4  This month in Vastgoedactueel why it is import...

# %%
#create function to get subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#create function to get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

#apply function to data 
df_new['Subjectivity'] = df_new['Tweet_Clean'].apply(getSubjectivity)
df_new['Polarity'] = df_new['Tweet_Clean'].apply(getPolarity)
df_new.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                                          Tweet_Clean  Subjectivity  Polarity
# 0  “8 out of 10 starters experience the current h...          0.40     0.000
# 1   Free sector rental prices on the rise again  ...          0.60     0.125
# 2  Attention starters  Will you help us map the p...          0.00     0.000
# 3  The average m2 price of rental homes in the fr...          0.60     0.125
# 4  This month in Vastgoedactueel why it is import...          0.65     0.250

# %%
#create function to get sentiment data
def getSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

#apply function to data
df_new['Sentiment'] = df_new['Polarity'].apply(getSentiment)
df_new.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                                          Tweet_Clean  ...  Sentiment
# 0  “8 out of 10 starters experience the current h...  ...    Neutral
# 1   Free sector rental prices on the rise again  ...  ...   Positive
# 2  Attention starters  Will you help us map the p...  ...    Neutral
# 3  The average m2 price of rental homes in the fr...  ...   Positive
# 4  This month in Vastgoedactueel why it is import...  ...   Positive
#
# [5 rows x 4 columns]

# %%
#visualize positive of tweet sentiment
positive = " ".join(df_new[df_new.Sentiment == 'Positive']['Tweet_Clean'].values)
w = WordCloud(width = 700, height = 400, random_state = 10, max_font_size = 100).generate(positive)

plt.figure(figsize = (10,6))
plt.imshow(w, interpolation = "bilinear")
plt.title("Wordcloud of Positive Tweet")
plt.axis('off')
plt.show()

# %%
#visualize neutral of tweet sentiment
neutral = " ".join(df_new[df_new.Sentiment == 'Neutral']['Tweet_Clean'].values)
w = WordCloud(width = 700, height = 400, random_state = 10, max_font_size = 100, colormap = 'Set1').generate(neutral)

plt.figure(figsize = (10,6))
plt.imshow(w, interpolation = "bilinear")
plt.title("Wordcloud of Neutral Tweet")
plt.axis('off')
plt.show()

# %%
#visualize negative of tweet sentiment
negative = " ".join(df_new[df_new.Sentiment == 'Negative']['Tweet_Clean'].values)
w = WordCloud(width = 700, height = 400, random_state = 10, max_font_size = 100, colormap = 'Set2').generate(negative)

plt.figure(figsize = (10,6))
plt.imshow(w, interpolation = "bilinear")
plt.title("Wordcloud of Negative Tweet")
plt.axis('off')
plt.show()

# %%
#visualize sentiment
plt.figure(figsize = (8,6))
plt.xlabel('Sentiment')
plt.ylabel('Count')
chart = df_new['Sentiment'].value_counts().plot(kind = 'bar', color = 'lightseagreen')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 1)
plt.title("Sentiment Analysis of Tweet")
plt.show()

# %% [markdown]
# #✅ Random Forest Model

# %%
#selection data
join = (df['Name'], df['Location'], text['Tweet_Clean'], df['Area'], df['Price'], df_new['Sentiment'])
df1 = pd.concat(join, axis = True)
df1.head()
# Out:
#                         Name  ... Sentiment
# 0  Apartment Melis Stokelaan  ...   Neutral
# 1   Apartment Loosduinsekade  ...  Positive
# 2        Apartment Maystraat  ...   Neutral
# 3     Apartment Altingstraat  ...  Positive
# 4     Apartment Stevinstraat  ...  Positive
#
# [5 rows x 6 columns]

# %%
#transform data to categorical variable
df1['Name'] = df1['Name'].astype('category').cat.codes
df1['Location'] = df1['Location'].astype('category').cat.codes
df1['Tweet_Clean'] = df1['Tweet_Clean'].astype('category').cat.codes
print(df1.dtypes)
# Out:
# Name             int8
# Location         int8
# Tweet_Clean      int8
# Area            int64
# Price           int64
# Sentiment      object
# dtype: object

# %%
#feature scaling
le = LabelEncoder()
le.fit_transform(df1['Sentiment'])
# Out:
# array([1, 2, 1, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 1, 1,
#        2, 2, 1, 1, 1, 2, 0, 1])

# %%
#split data
X = df1.drop('Sentiment', axis = 1)
y = df1['Sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (21, 5)
# (21,)
# (9, 5)
# (9,)

# %%
#build model
rf = RandomForestClassifier(random_state = 1, max_features = 'sqrt', n_jobs = 1, verbose = 1)
# %time rf.fit(X_train, y_train)
accuracy = rf.score(X_test, y_test)
print('Accuracy Score : ', int(accuracy * 100), '%')
# Out:
# CPU times: user 141 ms, sys: 754 µs, total: 142 ms
# Wall time: 142 ms
# Accuracy Score :  33 %
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
#prediction
y_pred = rf.predict(X_test)
print(y_pred)
# Out:
# ['Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Negative' 'Negative']
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
#confusion matrix
matrix = metrics.confusion_matrix(y_test, y_pred)
print(matrix)

#heatmap matrix
plt.figure(figsize = (8,6))
sns.heatmap(matrix, vmax = 0.9, annot = True, cmap = 'viridis')
plt.title("Confusion Matrix")
plt.xlabel("Prediction")
plt.ylabel("Actual")
plt.show()
# Out:
# [[0 0 1]
#  [1 0 2]
#  [2 0 3]]

# %%
#classification report
report = metrics.classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         1
#      Neutral       0.00      0.00      0.00         3
#     Positive       0.50      0.60      0.55         5
#
#     accuracy                           0.33         9
#    macro avg       0.17      0.20      0.18         9
# weighted avg       0.28      0.33      0.30         9
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #✅ Check Feature Importance

# %%
#defining feature
feature = pd.Series(rf.feature_importances_, index = X_train.columns).sort_values(ascending = False)
print(feature)
# Out:
# Tweet_Clean    0.252399
# Area           0.244003
# Name           0.192710
# Price          0.186333
# Location       0.124554
# dtype: float64

# %%
#visualize feature
plt.figure(figsize = (8,6))
sns.barplot(x = feature.index, y = feature, palette = 'Set1')
plt.title("Feature Importance")
plt.xlabel('Features')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #✅ Linear Regression Model

# %%
#selection data
df2 = df[['Name', 'Location', 'Area', 'Price']]
df2.head()
# Out:
#                         Name  ... Price
# 0  Apartment Melis Stokelaan  ...   505
# 1   Apartment Loosduinsekade  ...  1395
# 2        Apartment Maystraat  ...  1495
# 3     Apartment Altingstraat  ...  1175
# 4     Apartment Stevinstraat  ...  1350
#
# [5 rows x 4 columns]

# %%
#handling categorical data
df2 = pd.get_dummies(df2, drop_first = True)
df2.head()
# Out:
#    Area  ...  Location_            2593 VW Den Haag (Bezuidenhout-Oost)
# 0    44  ...                                                  0
# 1    78  ...                                                  0
# 2    83  ...                                                  1
# 3    90  ...                                                  0
# 4    69  ...                                                  0
#
# [5 rows x 57 columns]

# %%
#split data
X = df2.drop('Price', axis = 1)
y = df2['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (21, 56)
# (9, 56)
# (21,)
# (9,)

# %%
#build model 
lr = LinearRegression()
# %time lr.fit(X_train, y_train)
# Out:
# CPU times: user 2.14 ms, sys: 3.81 ms, total: 5.95 ms
# Wall time: 24.2 ms
# LinearRegression()

# %%
#prediction
y_pred = lr.predict(X_test)
print(y_pred)
# Out:
# [1353.15774775 1091.01186256 1226.31296459  871.14757177 1217.85664572
#   904.97284727 1454.63357427 1128.08736225  904.97284727]

# %%
#visualize actual & prediction
plt.figure(figsize = (10, 6))
ax = sns.distplot(y, hist = True, color = "r", label = "Actual")
sns.distplot(y_pred, hist = True, color = "b", label = "Predicted" , ax = ax)
plt.title('Actual vs Predicted for Price')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#check MAE, MSE, R-Squared & RMSE
print('Mean Absolute Error : ', metrics.mean_absolute_error(y_test, y_pred).round(2))
print('Mean Squared Error : ', metrics.mean_squared_error(y_test, y_pred).round(2))
print('Root Mean Squared Error : ', np.sqrt(metrics.mean_absolute_error(y_test, y_pred).round(2)))
print('R-Squared : ', metrics.r2_score(y_test, y_pred, multioutput = 'variance_weighted'))
# Out:
# Mean Absolute Error :  129.83
# Mean Squared Error :  25327.78
# Root Mean Squared Error :  11.394296819023104
# R-Squared :  0.7337723952060463

# %%
#visualize model
x = y_test
y = y_pred

plt.figure(figsize = (10,6))
plt.title("Linear Regression Model")
plt.plot(x, y, 'o', color = 'r')

m, b = np.polyfit(x, y, 1)
plt.plot(x, m * x + b, color = 'darkblue')

# %%
#distribution
plt.figure(figsize = (10,6))
sns.distplot(df['Price'], color = 'r')
plt.title("Distribution of Price")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #✅ Check Feature Importance

# %%
#defining feature
coef = pd.Series(lr.coef_, index = X.columns)

imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])

# %%
#visualize feature
plt.figure(figsize = (10,6))
imp_coef.plot(kind = 'barh', color = 'orange')
plt.title("Feature Importance")
plt.xlabel('Score')
plt.ylabel('Features')
plt.show()
